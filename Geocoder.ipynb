# %%
import mysql.connector
import geocoder
from geopy.geocoders import Nominatim
import pandas as pd

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Barista_4445!",
  database="practicedb1"
)

mycursor = mydb.cursor()

# %%
mycursor.execute(
    """SELECT DISTINCT(n.UniqueID), 
            n2.ownersplitaddress,
            n2.ownersplitcity,
            n2.ownersplitstate
        FROM nashville_housing AS n
        LEFT JOIN nashville_housing AS n2
        ON n.UniqueID = n2.UniqueID
        """)

myresult = mycursor.fetchall()

# %%
query = """SELECT DISTINCT(n.UniqueID), 
            n2.ownersplitaddress,
            n2.ownersplitcity,
            n2.ownersplitstate
        FROM nashville_housing AS n
        LEFT JOIN nashville_housing AS n2
        ON n.UniqueID = n2.UniqueID;
        """

df = pd.read_sql(query, mydb)
df
# Out:
#        UniqueID               ownersplitaddress   ownersplitcity  \
# 0          2045              1808  FOX CHASE DR   GOODLETTSVILLE
# 1         16918              1832  FOX CHASE DR   GOODLETTSVILLE
# 2         54582              1864  FOX CHASE DR   GOODLETTSVILLE
# 3         43070              1853  FOX CHASE DR   GOODLETTSVILLE
# 4         22714              1829  FOX CHASE DR   GOODLETTSVILLE
# ...         ...                             ...              ...
# 25663     43543           4912  HICKORY WOODS E          ANTIOCH
# 25664     33753  4480  LAVERGNE COUCHVILLE PIKE          ANTIOCH
# 25665      1444                109  SUNSHINE CT          ANTIOCH
# 25666     37171          5157  HICKORY GROVE DR          ANTIOCH
# 25667     20731                   6635  HOLT RD        NASHVILLE
#
#       ownersplitstate
# 0                  TN
# 1                  TN
# 2                  TN
# 3                  TN
# 4                  TN
# ...               ...
# 25663              TN
# 25664              TN
# 25665              TN
# 25666              TN
# 25667              TN
#
# [25668 rows x 4 columns]

# %%
df['combined_address'] = df['ownersplitaddress'] + ', Tennessee, USA'
df
# Out:
#        UniqueID               ownersplitaddress   ownersplitcity  \
# 0          2045              1808  FOX CHASE DR   GOODLETTSVILLE
# 1         16918              1832  FOX CHASE DR   GOODLETTSVILLE
# 2         54582              1864  FOX CHASE DR   GOODLETTSVILLE
# 3         43070              1853  FOX CHASE DR   GOODLETTSVILLE
# 4         22714              1829  FOX CHASE DR   GOODLETTSVILLE
# ...         ...                             ...              ...
# 25663     43543           4912  HICKORY WOODS E          ANTIOCH
# 25664     33753  4480  LAVERGNE COUCHVILLE PIKE          ANTIOCH
# 25665      1444                109  SUNSHINE CT          ANTIOCH
# 25666     37171          5157  HICKORY GROVE DR          ANTIOCH
# 25667     20731                   6635  HOLT RD        NASHVILLE
#
#       ownersplitstate                                combined_address
# 0                  TN              1808  FOX CHASE DR, Tennessee, USA
# 1                  TN              1832  FOX CHASE DR, Tennessee, USA
# 2                  TN              1864  FOX CHASE DR, Tennessee, USA
# 3                  TN              1853  FOX CHASE DR, Tennessee, USA
# 4                  TN              1829  FOX CHASE DR, Tennessee, USA
# ...               ...                                             ...
# 25663              TN           4912  HICKORY WOODS E, Tennessee, USA
# 25664              TN  4480  LAVERGNE COUCHVILLE PIKE, Tennessee, USA
# 25665              TN                109  SUNSHINE CT, Tennessee, USA
# 25666              TN          5157  HICKORY GROVE DR, Tennessee, USA
# 25667              TN                   6635  HOLT RD, Tennessee, USA
#
# [25668 rows x 5 columns]

# %%
addresses = df['combined_address']
addresses
# Out:
# 0                    1808  FOX CHASE DR, Tennessee, USA
# 1                    1832  FOX CHASE DR, Tennessee, USA
# 2                    1864  FOX CHASE DR, Tennessee, USA
# 3                    1853  FOX CHASE DR, Tennessee, USA
# 4                    1829  FOX CHASE DR, Tennessee, USA
#                               ...
# 25663             4912  HICKORY WOODS E, Tennessee, USA
# 25664    4480  LAVERGNE COUCHVILLE PIKE, Tennessee, USA
# 25665                  109  SUNSHINE CT, Tennessee, USA
# 25666            5157  HICKORY GROVE DR, Tennessee, USA
# 25667                     6635  HOLT RD, Tennessee, USA
# Name: combined_address, Length: 25668, dtype: object

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

places = ['1808  FOX CHASE DR, Tennessee, USA', '1832  FOX CHASE DR, Tennessee, USA', '4912  HICKORY WOODS E, Tennessee, USA', '4480  LAVERGNE COUCHVILLE PIKE, Tennessee, USA', '109  SUNSHINE CT, Tennessee, USA']

for i in places:
    location = geolocator.geocode(i)
    print(location)
# Out:
# 1808, Fox Chase Drive, Nashville-Davidson, Davidson County, Tennessee, 37072, United States
# 1832, Fox Chase Drive, Nashville-Davidson, Davidson County, Tennessee, 37072, United States
# 4912, Hickory Woods East, Nashville-Davidson, Davidson County, Tennessee, 37013, United States
# 4480, Lavergne Couchville Pike, Nashville-Davidson, Davidson County, Tennessee, 37013, United States
# 109, Sunshine Court, Nashville-Davidson, Davidson County, Tennessee, 37013, United States

# %%
#for i in addresses:
#    lat_long = geocoder.google(i)
#    print(i, lat_long.latlng)

# %% [markdown]
# ### I opted not to try to pull in zip codes and coordinates with geocoder modules for this dataset, as it would have taken over 3.5 hours.
